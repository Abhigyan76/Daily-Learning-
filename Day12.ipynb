# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhigyan76/Movie-Recommendation-System/blob/main/Day12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
reviews=pd.read_csv("/content/winemag-data-130k-v2.csv")

# %%
reviews
# Out:
#        Unnamed: 0   country  \
# 0               0     Italy
# 1               1  Portugal
# 2               2        US
# 3               3        US
# 4               4        US
# ...           ...       ...
# 25856       25856    France
# 25857       25857    France
# 25858       25858        US
# 25859       25859     Spain
# 25860       25860     Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 25856  This is a firmly structured wine, but its blac...
# 25857  This taut, structured wine achieves a balance ...
# 25858  A faint yeastiness subsides to expose luxuriou...
# ...

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
desc=reviews.describe()
desc
# Out:
#          Unnamed: 0        points         price
# count  25861.000000  25861.000000  23982.000000
# mean   12930.000000     88.383589     34.875448
# std     7465.571992      2.994496     41.085264
# min        0.000000     80.000000      4.000000
# 25%     6465.000000     86.000000     17.000000
# 50%    12930.000000     88.000000     25.000000
# 75%    19395.000000     91.000000     42.000000
# max    25860.000000    100.000000   2500.000000

# %% [markdown]
# Select the first value from the description column of reviews, assigning it to variable first_description.

# %%
first_description = reviews.country

# %%
first_description
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#            ...
# 25856      France
# 25857      France
# 25858          US
# 25859       Spain
# 25860       Spain
# Name: country, Length: 25861, dtype: object

# %% [markdown]
# If we have python dictionary,we can acess its value using index[]

# %%
reviews['country']
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#            ...
# 25856      France
# 25857      France
# 25858          US
# 25859       Spain
# 25860       Spain
# Name: country, Length: 25861, dtype: object

# %% [markdown]
# Select the first row of data (the first record) from `reviews`, assigning it to the variable `first_row`.

# %%
first_row = reviews.iloc[0] #iloc is used for index based selection
first_row
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %% [markdown]
# Label-based selection

# %%
reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
reviews.iloc[-5:]
# Out:
#        Unnamed: 0 country                                        description  \
# 25856       25856  France  This is a firmly structured wine, but its blac...
# 25857       25857  France  This taut, structured wine achieves a balance ...
# 25858       25858      US  A faint yeastiness subsides to expose luxuriou...
# 25859       25859   Spain  Earth, cola, berry, toast and leather aromas s...
# 25860       25860   Spain  Mineral-driven and hard on the nose, this feat...
#
#                                    designation  points  price    province  \
# 25856                       Domaine Javernière      88    NaN  Beaujolais
# 25857                                La Madone      88    NaN  Beaujolais
# 25858                   Hobbit Hollow Vineyard      88   27.0    New York
# 25859                                 Gaubança      88   28.0   Catalonia
# 25860  Vinyes Velles Nobles Garnatxa-Carinyena      88   20.0   Catalonia
#
# ...

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#               taster_name taster_twitter_handle  points
# 0           Kerin O’Keefe          @kerinokeefe      87
# 1              Roger Voss            @vossroger      87
# 2            Paul Gregutt           @paulgwine       87
# 3      Alexander Peartree                   NaN      87
# 4            Paul Gregutt           @paulgwine       87
# ...                   ...                   ...     ...
# 25856          Roger Voss            @vossroger      88
# 25857          Roger Voss            @vossroger      88
# 25858  Anna Lee C. Iijima                   NaN      88
# 25859   Michael Schachner           @wineschach      88
# 25860   Michael Schachner           @wineschach      88
#
# [25861 rows x 3 columns]

# %% [markdown]
# Manipulating the index

# %%
reviews.set_index("title")
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# Georges Duboeuf 2011 Domaine Javernière  (Morgon)        25856    France
# Georges Duboeuf 2011 La Madone  (Fleurie)                25857    France
# Heart & Hands 2011 Hobbit Hollow Vineyard Riesl...       25858        US
# Pahí Poboleda 2009 Gaubança Red (Priorat)                25859     Spain
# Acústic                                                  25860     Spain
#
# ...

# %% [markdown]
# Conditional selection

# %%
reviews.country == 'Italy'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25856    False
# 25857    False
# 25858    False
# 25859    False
# 25860    False
# Name: country, Length: 25861, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#        Unnamed: 0 country                                        description  \
# 0               0   Italy  Aromas include tropical fruit, broom, brimston...
# 6               6   Italy  Here's a bright, informal red that opens with ...
# 13             13   Italy  This is dominated by oak and oak-driven aromas...
# 22             22   Italy  Delicate aromas recall white flower and citrus...
# 24             24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...           ...     ...                                                ...
# 25816       25816   Italy  Mature black plum, tobacco, crushed violet, ca...
# 25825       25825   Italy  Aromas of baked plum, espresso, dark spice, le...
# 25849       25849   Italy  This expression is rich and smooth, with silky...
# 25850       25850   Italy  From the cool-climate north of Italy, this fre...
# 25851       25851   Italy  Here's a bright, food-friendly bottling that o...
#
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        Unnamed: 0 country                                        description  \
# 120           120   Italy  Slightly backward, particularly given the vint...
# 130           130   Italy  At the first it was quite muted and subdued, b...
# 133           133   Italy  Einaudi's wines have been improving lately, an...
# 135           135   Italy  The color is just beginning to show signs of b...
# 140           140   Italy  A big, fat, luscious wine with plenty of toast...
# ...           ...     ...                                                ...
# 25759       25759   Italy  Full-bodied and elegant, it discloses aromas o...
# 25800       25800   Italy  Fresh, alluring aromas of wild berry, pressed ...
# 25806       25806   Italy  Dark-skinned berry, culinary spice and a balsa...
# 25816       25816   Italy  Mature black plum, tobacco, crushed violet, ca...
# 25825       25825   Italy  Aromas of baked plum, espresso, dark spice, le...
#
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        Unnamed: 0 country                                        description  \
# 0               0   Italy  Aromas include tropical fruit, broom, brimston...
# 6               6   Italy  Here's a bright, informal red that opens with ...
# 13             13   Italy  This is dominated by oak and oak-driven aromas...
# 22             22   Italy  Delicate aromas recall white flower and citrus...
# 24             24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...           ...     ...                                                ...
# 25825       25825   Italy  Aromas of baked plum, espresso, dark spice, le...
# 25826       25826      US  One of the top wines from Lake County, this is...
# 25849       25849   Italy  This expression is rich and smooth, with silky...
# 25850       25850   Italy  From the cool-climate north of Italy, this fre...
# 25851       25851   Italy  Here's a bright, food-friendly bottling that o...
#
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        Unnamed: 0 country                                        description  \
# 0               0   Italy  Aromas include tropical fruit, broom, brimston...
# 6               6   Italy  Here's a bright, informal red that opens with ...
# 7               7  France  This dry and restrained wine offers spice in p...
# 9               9  France  This has great depth of flavor with its fresh ...
# 11             11  France  This is a dry wine, very spicy, with a tight, ...
# ...           ...     ...                                                ...
# 25849       25849   Italy  This expression is rich and smooth, with silky...
# 25850       25850   Italy  From the cool-climate north of Italy, this fre...
# 25851       25851   Italy  Here's a bright, food-friendly bottling that o...
# 25856       25856  France  This is a firmly structured wine, but its blac...
# 25857       25857  France  This taut, structured wine achieves a balance ...
#
# ...

# %%
reviews['critic'] = 'everyone'  #Assigning data
reviews['critic']
# Out:
# 0        everyone
# 1        everyone
# 2        everyone
# 3        everyone
# 4        everyone
#            ...
# 25856    everyone
# 25857    everyone
# 25858    everyone
# 25859    everyone
# 25860    everyone
# Name: critic, Length: 25861, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0        25861
# 1        25860
# 2        25859
# 3        25858
# 4        25857
#          ...
# 25856        5
# 25857        4
# 25858        3
# 25859        2
# 25860        1
# Name: index_backwards, Length: 25861, dtype: int64
